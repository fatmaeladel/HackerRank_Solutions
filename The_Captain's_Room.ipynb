# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmaeladel/HackerRank_Solutions/blob/main/The_Captain's_Room.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![لقطة شاشة 2025-12-18 170646.png](data:image/png;base64,...)

# %%
k=int(input())
r=list(map(int,input().split()))
rs=set(r)
cr =(sum(set(rs)) * k - sum(r)) // (k - 1)
print(cr)

## will show error in some cases
##for i in r:
    ##if r.count(i)==1:
        ##print(i)
# Out:
# 5
# 1 2 3 6 5 4 4 2 5 3 6 1 6 5 3 2 4 1 2 5 1 4 3 6 8 4 3 1 5 6 2
# 8
