# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmaeladel/HackerRank_Solutions/blob/main/Power_Mod_Power.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![لقطة شاشة 2025-12-18 185026.png](data:image/png;base64,...)

# %%
a=int(input())
b=int(input())
m=int(input())
print(pow(a , b))
print(pow(a,b,m))
# Out:
# 3
# 4
# 5
# 81
# 1
