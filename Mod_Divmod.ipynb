# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmaeladel/HackerRank_Solutions/blob/main/Mod_Divmod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![لقطة شاشة 2025-12-18 184508.png](data:image/png;base64,...)

# %%
a =int(input())
b =int(input())
print(a//b)
print(a%b)
print(divmod(a , b))
# Out:
# 177
# 10
# 17
# 7
# (17, 7)
