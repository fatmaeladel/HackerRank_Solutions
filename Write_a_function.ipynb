# %% [markdown]
# ![لقطة شاشة 2025-12-12 112601.png](data:image/png;base64,...)

# %%
def is_leap(year):
    return year%4==0 and (year%100!=0 or year%400==0)

year = int(input())
print(is_leap(year))
