# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmaeladel/HackerRank_Solutions/blob/main/Set_union()_Operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![لقطة شاشة 2025-12-17 144227.png](data:image/png;base64,...)

# %%
ne=int(input())
e=set(map(int , input().split()))
nf=int(input())
f=set(map(int, input().split()))
t=set(e.union(f))
print(len(t))
# Out:
# 9
# 1 2 3 4 5 6 7 8 9
# 9
# 10 1 2 3 11 21 55 6 8
# 13
