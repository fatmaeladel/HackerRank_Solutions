# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmaeladel/HackerRank_Solutions/blob/main/Symmetric_Difference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![لقطة شاشة 2025-12-17 053547.png](data:image/png;base64,...)

# %%
M=input()
m=set(map(int, input().split()))
N=input()
n=set(map(int, input().split()))
z=m.intersection(n)
x=m.union(n)
y= x - z
print('\n'.join(map(str ,sorted(y))))
# Out:
# 4
# 2 4 5 9
# 4
# 2 4 11 12
# 5
# 9
# 11
# 12
