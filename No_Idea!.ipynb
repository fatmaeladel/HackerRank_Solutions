# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmaeladel/HackerRank_Solutions/blob/main/No_Idea!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![لقطة شاشة 2025-12-17 130421.png](data:image/png;base64,...)

# %%
n , m= map(int, input().split())
N= list(map(int , input().split()))
a=set(map(int,input().split()))
b=set(map(int , input().split()))
counter=0
for i in N:
    if i  in a:
        counter+=1
    elif i in b :
        counter-=1
print(counter)
# Out:
# 3 2
# 1 5 3
# 3 1
# 5 7
# 1
