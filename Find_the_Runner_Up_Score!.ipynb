# %% [markdown]
# ![لقطة شاشة 2025-12-12 114150.png](data:image/png;base64,...)

# %%
n = int(input())
S=list(map(int,input().split()))
s=list(set(S))
s.sort(reverse=True)
print(s[1])
# Out:
# 5
# 2 3 6 6 5
# 5
