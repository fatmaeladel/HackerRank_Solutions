# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmaeladel/HackerRank_Solutions/blob/main/Set_difference()_Operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![لقطة شاشة 2025-12-18 153858.png](data:image/png;base64,...)

# %%
ne=int(input())
e=set(input().split())
nf=int(input())
f=set(input().split())
d=e.difference(f)
print(len(d))
# Out:
# 9
# 1 2 3 4 5 6 7 8 9
# 9
# 10 1 2 3 11 21 55 6 8
# 4
