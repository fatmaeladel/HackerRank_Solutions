# %% [markdown]
# ![لقطة شاشة 2025-12-12 110235.png](data:image/png;base64,...)

# %%
n =int(input())
if (n%2!=0):
    print("Weird")
elif(n%2==0 and 5>=n>=2):
    print("Not Weird")
elif(n%2==0 and 20>=n>=6):
    print("Weird")
elif(n%2==0 and n>20):
    print("Not Weird")
# Out:
# 24
# Not Weird
