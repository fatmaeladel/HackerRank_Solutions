# %% [markdown]
# <a href="https://colab.research.google.com/github/fatmaeladel/HackerRank_Solutions/blob/main/Set_add().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![لقطة شاشة 2025-12-17 133416.png](data:image/png;base64,...)

# %%
n=int(input())
s=set()
for i in range(n):
    c=input()
    s.add(c)
print(len(s))
# Out:
# 7
# UK
# CHINA
# USA
# FRANCE
# NEW ZEALAND
# UK
# FRANCE
# 5
